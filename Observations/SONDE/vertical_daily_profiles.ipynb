# %% [markdown]
# ## Radiosonde/Reanalysis and Model Annual Profile Comprisons

# %%
import xarray as xr
import matplotlib.pyplot as mp
import pandas as pd
#import geocat.comp as gc
#import seaborn as sb
import scipy as sp

import numpy as np
import os
import glob as gb
import dask

from matplotlib.cm import get_cmap
from matplotlib.dates import DateFormatter,MonthLocator
from matplotlib import cm
from matplotlib.lines import Line2D

import cartopy.crs as ccrs
from cartopy.feature import NaturalEarthFeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.feature as cf
from cartopy.io import shapereader
import geopandas

import warnings

#warnings.filterwarnings("ignore")
# Silence dask.distributed logs
import logging



import importlib

# %%
import pandas as pd

# Example of reading a CSV or TXT file
data = pd.read_csv("path_to_raob_file.txt", delimiter="\s+", header=None)
print(data.head())

# %%
import xarray as xr

# Open the RAOB NetCDF file
data = xr.open_dataset("path_to_raob_file.nc")
print(data)

# %%
from metpy.io import get_upper_air_data
from datetime import datetime

# Specify a date and station for radiosonde data (e.g., 2024-11-13, station "72469" for Denver)
data = get_upper_air_data(datetime(2024, 11, 13, 0), "72469")
print(data)

# %%
profile_locations = ['Denver'] # Enter name of 
profile_sonde = True
profile_model = True
profile_analyses = True

sonde_dir =
# Out:
#   Cell In[2], line 6
#     sonde_dir =
#                 ^
# SyntaxError: invalid syntax
