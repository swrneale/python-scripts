# %% [markdown]
# ** Script to Examine Monthly Precipitation and Sea Surface Temperature

# %%
import xarray as xr
import numpy as np

import subprocess as sp
import glob as glob

# %%
# SST Dataset (every month 1850-2020)
sst_dataset = '/glade/p/cesmdata/cseg/inputdata/atm/cam/sst/sst_HadOIBl_bc_0.9x1.25_1850_2020_c210521.nc'
#prect_dataset = '/glade/work/rneale/data/GPCP/gpcp.mon.mean.197901-201607.nc'

# US precip
#us_prect_dataset1 = '/glade/work/rneale/data/Livneh/prec.mon.ltm.nc'
#us_prect_dataset2 = '/glade/work/rneale/data/NOAA_CPC_USA/precip.V1.0.mon.mean.nc'

var_dataset = sst_dataset

# Domain for averaging
xdom = [0,360] 
ydom = [-90,90]

# Read in SST dataset (xarray - see tips 
dvar = xr.open_dataset(var_dataset,decode_times = False)
var = dvar['SST_cpl'] 
var_nino = var.loc[:,ydom[0]:ydom[1],xdom[0]:xdom[1]]



var_nino
# Out:
# <xarray.DataArray 'SST_cpl' (time: 2064, lat: 190, lon: 288)>
# [112942080 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * lat      (lat) float64 -89.06 -88.12 -87.17 -86.23 ... 87.17 88.12 89.06
#   * time     (time) float64 15.5 45.0 74.5 ... 6.27e+04 6.273e+04 6.276e+04
# Attributes:
#     long_name:  BCS Pseudo SST
#     units:      deg_C

# %%
var_nino[0,:,:].plot()
var_nino
# Out:
# <xarray.DataArray 'SST_cpl' (time: 2064, lat: 190, lon: 288)>
# [112942080 values with dtype=float32]
# Coordinates:
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * lat      (lat) float64 -89.06 -88.12 -87.17 -86.23 ... 87.17 88.12 89.06
#   * time     (time) float64 15.5 45.0 74.5 ... 6.27e+04 6.273e+04 6.276e+04
# Attributes:
#     long_name:  BCS Pseudo SST
#     units:      deg_C

# %%
var_point = var_nino.sel(lon=200, lat=0, method='nearest')
var_point.plot()
