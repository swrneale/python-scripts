# %%
import numpy as np
from datetime import datetime
a = '20160228'
date = datetime.strptime(a, '%Y%m%d%f').strftime('%m%d%Y%f')
print(date)
# Out:
# 02022016800000

# %%
ccc = ['rich','rich2']
ddd = 'rich3'
ccc1=np.append(ccc,ddd)
print(ccc1)
# animals list
print(ccc)
# print(ddd)
# Out:
# ['rich' 'rich2' 'rich3']
# ['rich', 'rich2']
# rich3

# %%
# Test dp based on Z
from matplotlib.pyplot import plot, title, xlabel, ylabel, savefig, legend
from numpy import array

values = [(3, 4, 5), (5, 8, 9), (2, 3, 5), (3, 5, 6), (3, 5, 6, 7)]
days = array([24, 25, 26, 27, 28])

min_temp, avg_temp, max_temp = zip(*values)
temperature_with_colors_and_labels = (
    (min_temp, 'green', 'min'),
    (avg_temp, 'grey', 'avg'),
    (max_temp, 'orange', 'max'),
)

for temp, color, label in temperature_with_colors_and_labels:
    plot(days, array(temp), color=color, label=label)
title('Temperature at december (last decade)')
xlabel('Days of december')
ylabel('Temperature (Celsius)')
legend()

print(values)
# Out:
# [(3, 4, 5), (5, 8, 9), (2, 3, 5), (3, 5, 6), (3, 5, 6, 7)]
