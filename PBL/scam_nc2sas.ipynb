# %%
import numpy as np
import metpy.calc as mpc
import xarray as xr
import scipy.ndimage as ndimage
import pandas as pd
import csv as csv
import datetime as dt

# %%
### SCRIPT TO TRANSLATE DATA FROM SCAM NETCDF FILE TO SAS NETCDF FILE ####

###### IOP file(s) info. ######

scam_file_nums = ['101d'] # 'a'=L16, ''=L32
scam_run_names = ['CAM6']

scam_file_pre = "history/FSCAM.T42_T42.SAS."
scam_file_suf = ".cam.h0.2013-06-10-43200"

scam_files_in = [scam_file_pre+x+scam_file_suf for x in scam_file_nums]
print(scam_files_in)

### READ IN NETCDF FILE/SET UP OUTPUT FILE ####
scam_in = xr.open_dataset(scam_files_in[0]+'.nc')
#scam_sas =  xr.open_dataset(scam_files_in[0]+'_sas.format.nc')

# MakeDataSet copy
scam_out = scam_in.copy(deep=True)

# Tried to match the variable names as much as possible from here
# /glade/p/mmm/nmmm0058/patton/anl/3d

# SCAM name/LES name/LES units/scale -> LES
var_r = {}  # Long name/scam variable/units/scale
var_r['ts']         =   ['Simulations start time','bdate','[s]',1.] 
var_r['cs']         =   ['Chemistry start time','bdate','[s]',1.]          '
var_r['latitude']   =   ['Latitude','latitude','[def]',1.]           
var_r['longitude']   =  ['Longitude','longitude','[def]',1.]     
var_r['time']   =       ['Time','time','[s]',1.]  

#var_r['ustar'] = 
#var_r['wstar']   =       
#var_r['omonin']   = 

var_r['wqsfc']   = ['Surface water vapor specific humidity flux','time','[m/s kg/kg]',Lq]  
var_r['wtsfc']   = ['Surface potential temperature flux','time','[mK/s]',cp_air] 
var_r['t']   = 
var_r['tv']
var_r['q']   = 
var_r['zi_t']   = 
var_r['zi_q']   =
var_r['zu']   = 
var_r['u']   = 
var_r['v']   = 
var_r['w']   = 
var_r['p']   = 
var_r['tke_r']   = 
##var_r['uu_r']   = 
#var_r['uv_r']   = 
#var_r['uw_r']   = 
#var_r['vv_r']   = 
var_r['uuu_r']   = 
var_r['vvv_r']   = 
var_r['www_r']   = 

var_r['tt_r']   = 
#var_r['ttt_t']   = 
var_r['wt_r']   =
var_r['qq_r'] = 
var_r['wq_r']   = 
var_r['qqq_r'] =  

var_r['wtv_r']   = 
var_r['tttv_r']   = 
var_r['omonin']   = 






      
      'Q'     : ['q','kg/kg'],
             }''      : [])
var_r['missing_data'] =             
# Constajnts = [grav,p_ref,t_rtef,rd,rv,eps,vk,mwair,mwh20,missing_data]




print(var_rename.keys())

# Dict of data variables
scam_vars  = scam_out.data_vars 
#print(scam_vars)
# Array of all 'data' variable names
out_vars = list(scam_vars.keys())

# Subset variables to be dropped
drop_vars = [x for x in out_vars if x not in var_rename.keys()]

# Drop variables from output DataSet
#print(drop_vars)
scam_out = scam_out.drop_vars(drop_vars)

#------ Special variables ------#

## Total precipitation ##
scam_out['tp']=scam_in['PRECC']+scam_in['PRECL']
scam_out.tp.attrs['long_name'] = 'Total Precipitation'
scam_out.tp.attrs['units'] = 'm/s'

# Rename variables required for compatibility

print(scam_out['tp'].attrs)
# New variables to add.

#ds.rename({'temperature': 'temp', 'precipitation': 'precip'})
# Out:
# ['history/FSCAM.T42_T42.SAS.101d.cam.h0.2013-06-10-43200']
# dict_keys(['T', 'wt_s'])
# {'long_name': 'Total PRecipitation', 'units': 'm/s'}
