# %%
rset_dic = {}
rset_dic['E3SMv2'] = [[1,2,3], 3,'v2.FV1.historical_',100,'b','-',1.5]

# %%
print(rset_dic)
print(
# Out:
# {'E3SMv2': [[1, 2, 3], 3, 'v2.FV1.historical_', 100, 'b', '-', 1.5]}

# %%
rset_dic['E3SMv1'] = [['yo1','yo2'], 3,'v2.FV1.historical_',100,'b','-',1.5]

# %%
print(rset_dic['E3SMv1'][0])
# Out:
# ['yo1', 'yo2']

# %%
print(rset_dic)
# Out:
# {'E3SMv2': [[1, 2, 3], 3, 'v2.FV1.historical_', 100, 'b', '-', 1.5], 'E3SMv1': [['yo1', 'yo2'], 3, 'v2.FV1.historical_', 100, 'b', '-', 1.5]}

# %%
str1 = 'rich1_rich2'
str1.replace('rich1','rich3', 1)
# Out:
# 'rich3_rich2'
