# %%
    import pandas as pd
   
    import datetime as dt
    from dateutil.relativedelta import relativedelta

    dir(dt.datetime)
#
#    now = dt.datetime.today()
#    ff = now+relativedelta(months=+1)
#    print(ff)

#    x = 1
    
#    print(['red' else if x==1 'blue'])
#    rl = {} # Revert List
    
# LESN1

#    e0=1 ; en=10

#    erun = ['b.e11.B20TRC5CNBDRD.f09_g16.%03d'%(itt) for itt in range(e0,en+1)]
#    enum = ['E%01d'%(itt) for itt in range(e0,en+1)]
   
    
#    print(erun)
#    print(enum)
    
#    for it in range(e0,en+1):
#        rl[enum[it-1]] = erun[it-1]
        
#    display(rl)
    
    
   
    
#    rl['e1']   =  ['b.e11.B20TRC5CNBDRD.f09_g16.001']
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'astimezone',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'dst',
#  'fold',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'hour',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'microsecond',
#  'min',
#  'minute',
#  'month',
#  'now',
#  'replace',
#  'resolution',
#  'second',
#  'strftime',
#  'strptime',
#  'time',
#  'timestamp',
#  'timetuple',
#  'timetz',
#  'today',
#  'toordinal',
#  'tzinfo',
#  'tzname',
#  'utcfromtimestamp',
#  'utcnow',
#  'utcoffset',
#  'utctimetuple',
#  'weekday',
# ...
