# %%
import importlib
import vproc_main as mypy

# %%
from distributed import Client
from ncar_jobqueue import NCARCluster

cluster = NCARCluster()
cluster.scale(jobs=18)
# Out:
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/dask_jobqueue/core.py:255: FutureWarning: job_extra has been renamed to job_extra_directives. You are still using it (even if only set to []; please also check config files). If you did not set job_extra_directives yet, job_extra will be respected for now, but it will be removed in a future release. If you already set job_extra_directives, job_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/dask_jobqueue/core.py:274: FutureWarning: env_extra has been renamed to job_script_prologue. You are still using it (even if only set to []; please also check config files). If you did not set job_script_prologue yet, env_extra will be respected for now, but it will be removed in a future release. If you already set job_script_prologue, env_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/dask_jobqueue/pbs.py:82: FutureWarning: project has been renamed to account as this kwarg was used wit -A option. You are still using it (please also check config files). If you did not set account yet, project will be respected for now, but it will be removed in a future release. If you already set account, project is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/dask_jobqueue/core.py:255: FutureWarning: job_extra has been renamed to job_extra_directives. You are still using it (even if only set to []; please also check config files). If you did not set job_extra_directives yet, job_extra will be respected for now, but it will be removed in a future release. If you already set job_extra_directives, job_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/dask_jobqueue/core.py:274: FutureWarning: env_extra has been renamed to job_script_prologue. You are still using it (even if only set to []; please also check config files). If you did not set job_script_prologue yet, env_extra will be respected for now, but it will be removed in a future release. If you already set job_script_prologue, env_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/dask_jobqueue/pbs.py:82: FutureWarning: project has been renamed to account as this kwarg was used wit -A option. You are still using it (please also check config files). If you did not set account yet, project will be respected for now, but it will be removed in a future release. If you already set account, project is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)

# %%
client = Client(cluster)
client
# Out:
# <Client: 'tcp://10.12.206.47:37005' processes=0 threads=0, memory=0 B>

# %%
importlib.reload(mypy)

if __name__ == "__main__":
    mypy.main()
# Out:
# +++++++++++  CASE TYPES ++++++++++++
# ['lens']
# Index(['Nino Wet', 'WP Dry', 'Conv U'], dtype='object')
# reg= Nino Wet
# reg= WP Dry
# reg= Conv U
#                     long_name  lat_s  lat_n  lon_w  lon_e
# Nino Wet  C. Pacific Nino Wet  -10.0    0.0  160.0    220
# WP Dry    West Pac. Nino Dry.    0.0   15.0  110.0    150
# Conv U        Convergence Min   25.0   40.0  150.0    200
#                       long_name        vscale      ovscale     xmin     xmax  \
# DTCOND              dT/dt Total  8.640000e+04     1.000000  -5.0000   5.0000
# DCQ                 dq/dt Total  8.640000e+07     1.000000  -4.0000   4.0000
# ZMDT           dT/dt Convection  8.640000e+04     1.000000  -5.0000   5.0000
# ZMDQ           dq/dt Convection  8.640000e+07     1.000000  -4.0000   4.0000
# MPDT         dT/dt Microphysics  8.605578e+01     1.000000  -5.0000   5.0000
# STEND_CLUBB    dT/dt turbulence  8.605578e+01     1.000000  -2.0000   8.0000
# OMEGA         Vertical Velocity  1.000000e+00    -1.000000  -0.0600   0.0600
# DIV                  Divergence  1.000000e+00     0.001157  -0.0004   0.0004
# T                   Temperature  1.000000e+00     1.000000 -10.0000  10.0000
# Q             Specific Humidity  1.000000e+03  1000.000000   0.0000  20.0000
# U                    Zonal Wind  1.000000e+00     1.000000 -60.0000  60.0000
#
#                axmin    axmax    vunits
# DTCOND       -2.0000   2.0000     K/day
# DCQ          -4.0000   4.0000  g/kg/day
# ZMDT         -2.0000   2.0000     K/day
# ZMDQ         -4.0000   4.0000  g/kg/day
# MPDT         -2.0000   2.0000     K/day
# STEND_CLUBB  -2.0000   8.0000     K/day
# OMEGA        -0.0600   0.0600      pa/s
# DIV          -0.0004   0.0004      s^-1
# T           -10.0000  10.0000         K
# Q            -1.0000   1.0000      g/kg
# U           -10.0000  10.0000       m/s
# Nino Wet
#  -- Constucting Custom Legend for Vertical Profile Line Plots --
#
#
#
# **** **** **** **** **** **** **** **** ****
# **** CASE #  1  OF  2  ****
# **** **** **** **** **** **** **** **** ****
# - Name =  CE1.E1  -> b.e11.B20TRC5CNBDRD.f09_g16.001
# **** **** **** **** **** **** **** **** ****
#
# -- SET TIME RANGE OF TIMESERIES DATA --  1979  to  1984
#
# -- Grabbing variable files --
# -- case_type files - type allowed
#     -- Grabbing data type/case -- lens1 b.e11.B20TRC5CNBDRD.f09_g16.001
#     -- Grabbing file(s) for LENS1(CESM1) - Variable =  OMEGA
#     -- PROCESSING FILE(S) ->>
#     --> Single file
#     - /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/monthly/OMEGA/b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.OMEGA.185001-200512.nc
#     -- FILE(S) AVAILABLE TIME RANGE - >  1979  to 1984
#
# Dataset required memory = 199084728
# -- Grabbing Sea Surface Temperature (SST) files --
# -- case_type files - type allowed
#     -- Grabbing data type/case -- lens1 b.e11.B20TRC5CNBDRD.f09_g16.001
#     -- Grabbing file(s) for LENS1(CESM1) - Variable =  TS
#     -- PROCESSING FILE(S) ->>
#     --> Single file
#     - /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/monthly/TS/b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.TS.185001-200512.nc
#     -- FILE(S) AVAILABLE TIME RANGE - >  1979  to 1984
#
# Dataset required memory = 7981872
# -- Grabbing Surface Pressure (PS) files --
# -- case_type files - type allowed
#     -- Grabbing data type/case -- lens1 b.e11.B20TRC5CNBDRD.f09_g16.001
#     -- Grabbing file(s) for LENS1(CESM1) - Variable =  PS
#     -- PROCESSING FILE(S) ->>
#     --> Single file
#     - /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/monthly/PS/b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h0.PS.185001-200512.nc
#     -- FILE(S) AVAILABLE TIME RANGE - >  1979  to 1984
#
# Dataset required memory = 7981752
# -- Calculating and plotting nino SST anomalies - this will never be climo currently
#     > Calculating for SST anomalies  nino34  region
#     > Removing SST Annual Cycles --
#     > Setup SST Plotting --
#     > Calculating local plotting arrays --
#     > Plotting SST data --
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/matplotlib/contour.py:1479: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/matplotlib/contour.py:1480: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:1614: UserWarning: No contour levels were found within the data range.
#   result = super().contour(*args, **kwargs)
#     > Adding nino boxes --
#     > Saving figure --
# -- NINO grab:  Done --
# -- "Compute" the variable array now (bring it up from lazy array) if != ANALYSES
# Nino Wet
#
# -- Region =  C. Pacific Nino Wet  -  -10.0 0.0 160.0 220
# -- Averaging for region -  160-220°E -10.0-0°N
#     -- Period = Climatology (1979-1984)
#     -- Period = El Nino
#     -- Period = La Nina
# Nino Wet
#
# -- Region =  C. Pacific Nino Wet  -  -10.0 0.0 160.0 220
# -- Averaging for region -  160-220°E -10.0-0°N
#     -- Period = Climatology (1979-1984)
#     -- Period = El Nino
#     -- Period = La Nina
# Nino Wet
#
# -- Region =  C. Pacific Nino Wet  -  -10.0 0.0 160.0 220
# -- Averaging for region -  160-220°E -10.0-0°N
#     -- Period = Climatology (1979-1984)
#     -- Period = El Nino
#     -- Period = La Nina
#
#
#
# **** **** **** **** **** **** **** **** ****
# **** CASE #  2  OF  2  ****
# **** **** **** **** **** **** **** **** ****
# - Name =  CE1.E2  -> b.e11.B20TRC5CNBDRD.f09_g16.002
# **** **** **** **** **** **** **** **** ****
#
# -- SET TIME RANGE OF TIMESERIES DATA --  1979  to  1984
#
# -- Grabbing variable files --
# -- case_type files - type allowed
#     -- Grabbing data type/case -- lens1 b.e11.B20TRC5CNBDRD.f09_g16.002
#     -- Grabbing file(s) for LENS1(CESM1) - Variable =  OMEGA
#     -- PROCESSING FILE(S) ->>
#     --> Single file
#     - /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/monthly/OMEGA/b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h0.OMEGA.192001-200512.nc
#     -- FILE(S) AVAILABLE TIME RANGE - >  1979  to 1984
#
# Dataset required memory = 199084728
# -- Grabbing Sea Surface Temperature (SST) files --
# -- case_type files - type allowed
#     -- Grabbing data type/case -- lens1 b.e11.B20TRC5CNBDRD.f09_g16.002
#     -- Grabbing file(s) for LENS1(CESM1) - Variable =  TS
#     -- PROCESSING FILE(S) ->>
#     --> Single file
#     - /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/monthly/TS/b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h0.TS.192001-200512.nc
#     -- FILE(S) AVAILABLE TIME RANGE - >  1979  to 1984
#
# Dataset required memory = 7981872
# -- Grabbing Surface Pressure (PS) files --
# -- case_type files - type allowed
#     -- Grabbing data type/case -- lens1 b.e11.B20TRC5CNBDRD.f09_g16.002
#     -- Grabbing file(s) for LENS1(CESM1) - Variable =  PS
#     -- PROCESSING FILE(S) ->>
#     --> Single file
#     - /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/monthly/PS/b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h0.PS.192001-200512.nc
#     -- FILE(S) AVAILABLE TIME RANGE - >  1979  to 1984
#
# Dataset required memory = 7981752
# -- Calculating and plotting nino SST anomalies - this will never be climo currently
#     > Calculating for SST anomalies  nino34  region
#     > Removing SST Annual Cycles --
#     > Setup SST Plotting --
#     > Calculating local plotting arrays --
#     > Plotting SST data --
#     > Adding nino boxes --
#     > Saving figure --
# -- NINO grab:  Done --
# -- "Compute" the variable array now (bring it up from lazy array) if != ANALYSES
# Nino Wet
#
# -- Region =  C. Pacific Nino Wet  -  -10.0 0.0 160.0 220
# -- Averaging for region -  160-220°E -10.0-0°N
#     -- Period = Climatology (1979-1984)
#     -- Period = El Nino
#     -- Period = La Nina
# Nino Wet
#
# -- Region =  C. Pacific Nino Wet  -  -10.0 0.0 160.0 220
# -- Averaging for region -  160-220°E -10.0-0°N
#     -- Period = Climatology (1979-1984)
#     -- Period = El Nino
#     -- Period = La Nina
# Nino Wet
#
# -- Region =  C. Pacific Nino Wet  -  -10.0 0.0 160.0 220
# -- Averaging for region -  160-220°E -10.0-0°N
#     -- Period = Climatology (1979-1984)
#     -- Period = El Nino
#     -- Period = La Nina
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 importlib.reload(mypy)
#       3 if __name__ == "__main__":
# ----> 4     mypy.main()
#
# File /glade/work/rneale/git/python-scripts/vert_proc/vproc_main.py:425, in main()
#     415 mp.rcParams['xtick.labelsize'] = 15 # Global set of xtick label size
#     418 #    mp.show()
#     419
#     420
#    (...)
#     423
#     424 # Hard copy
# --> 425 fign.savefig(dir_proot+pref_out+'_nino_vprof_'+var1_cam[0]+'_'+reg_a_out+'_'+str(yr0)+'_to_'+str(yr1)+'.png', dpi=80)
#     427 #mp.show()
#     429 print()
#
# NameError: name 'var1_cam' is not defined
