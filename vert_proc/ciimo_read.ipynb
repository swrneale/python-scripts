# %% [markdown]
# ## - Read in DJF months separately for ERA5 climo, calculate weighted JDF average
# ## - Write to nino file formats for consistancy with other analayses.

# %%
import xarray as xr

# %%
file_djf_climo_in = 'ERA5_climo_DJF.nc'
file_djf_nino_in = 'ERA5_nino_DJF.nc'

dir_in = '/glade/work/rneale/data/ERA5/'

file_djf_climo_in = dir_in+file_djf_climo_in
file_djf_nino_in = dir_in+file_djf_nino_in

ds_climo = xr.open_mfdataset(file_djf_climo_in,parallel=True)
ds_nino = xr.open_mfdataset(file_djf_nino_in,parallel=True)

# %%
ds_climo
# Out:
# <xarray.Dataset>
# Dimensions:                (time: 12, lev: 37, lat: 721, lon: 1440)
# Coordinates:
#   * time                   (time) datetime64[ns] 1979-01-01 ... 1979-12-01
#   * lat                    (lat) float32 -90.0 -89.75 -89.5 ... 89.5 89.75 90.0
#   * lon                    (lon) float32 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * lev                    (lev) int32 1 2 3 5 7 10 ... 875 900 925 950 975 1000
# Data variables:
#     omega                  (time, lev, lat, lon) float32 dask.array<chunksize=(12, 37, 721, 1440), meta=np.ndarray>
#     initial_time0_encoded  (time) float64 dask.array<chunksize=(12,), meta=np.ndarray>
#     initial_time0          (time) |S18 dask.array<chunksize=(12,), meta=np.ndarray>
# Attributes:
#     history:                   Mon Nov 28 14:21:23 2022: ncrename -v OMEGA,om...
#     NCO:                       netCDF Operators version 5.0.3 (Homepage = htt...
#     nco_openmp_thread_number:  1
# ...

# %%
da_nino = ds_nino.drop_vars(['hgt','ua','va','ta','hus'])
da_nino
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 1440, lat: 721, lev: 32, time: 1)
# Coordinates:
#   * lon      (lon) float64 0.0 0.25 0.5 0.75 1.0 ... 359.0 359.2 359.5 359.8
#   * lat      (lat) float64 -90.0 -89.75 -89.5 -89.25 ... 89.25 89.5 89.75 90.0
#   * lev      (lev) float64 1e+03 975.0 950.0 925.0 900.0 ... 50.0 30.0 20.0 10.0
#   * time     (time) float64 1.201e+03
# Data variables:
#     omega    (time, lev, lat, lon) float32 dask.array<chunksize=(1, 32, 721, 1440), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version ?? (http://mpimet.mpg.de/cdi)
#     Conventions:  CF-1.4
#     history:      Thu Aug 19 14:17:28 2021: cdo -a -f nc import_binary anomal...
#     CDO:          Climate Data Operators version 1.7.0 (http://mpimet.mpg.de/...
