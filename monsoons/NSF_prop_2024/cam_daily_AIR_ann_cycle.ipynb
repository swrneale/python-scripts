# %% [markdown]
# ## Plot Monsoon climatological daily cumulative sum of AIR region precipitation

# %%
#%load_ext autoreload
#%autoreload 2
#%matplotlib inline

import xarray as xr
import matplotlib.pyplot as mp
import pandas as pd
#import geocat.comp as gc
#import seaborn as sb
import scipy as sp

import numpy as np
import os
import glob as gb
import dask

from matplotlib.cm import get_cmap
from matplotlib.dates import DateFormatter,MonthLocator
from matplotlib import cm
from matplotlib.lines import Line2D

import cartopy.crs as ccrs
from cartopy.feature import NaturalEarthFeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.feature as cf
from cartopy.io import shapereader
#import geopandas

import warnings

#warnings.filterwarnings("ignore")
# Silence dask.distributed logs
import logging

#logger = logging.getLogger("distributed.utils_perf")
#logger.setLevel(logging.ERROR)

#import holoviews as hv
#import hvplot.pandas
#import hvplot.xarray
#import intake

import importlib


### To Import My Functions ###
import daily_annual_cycle_calc as myplt

#import intake 
from distributed import Client
from ncar_jobqueue import NCARCluster

# %%
#cluster = NCARCluster()
#cluster.scale(10)
#client = Client(cluster)
#client
cluster = NCARCluster(project='P03010039',memory='32Gb',interface='ext', job_extra_directives=[], walltime ='12:00:00')
cluster.scale(18)
client = Client(cluster)
client
# Out:
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/dask_jobqueue/core.py:266: FutureWarning: job_extra has been renamed to job_extra_directives. You are still using it (even if only set to []; please also check config files). If you did not set job_extra_directives yet, job_extra will be respected for now, but it will be removed in a future release. If you already set job_extra_directives, job_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/dask_jobqueue/core.py:285: FutureWarning: env_extra has been renamed to job_script_prologue. You are still using it (even if only set to []; please also check config files). If you did not set job_script_prologue yet, env_extra will be respected for now, but it will be removed in a future release. If you already set job_script_prologue, env_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/dask_jobqueue/pbs.py:82: FutureWarning: project has been renamed to account as this kwarg was used wit -A option. You are still using it (please also check config files). If you did not set account yet, project will be respected for now, but it will be removed in a future release. If you already set account, project is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# <Client: 'tcp://128.117.208.117:34859' processes=0 threads=0, memory=0 B>

# %%
'''
    SET UP CASE
'''

reg_name = 'India'
#case_names = ['AIR','GPCP','TRMM']
case_names = ['AIR','TRMM','GPCP','E3SMv2','CESM2','CESM1']


var_name = 'PRECT' ; vscale = 86400.*1000.
years = ['1996','2005']
lpsave = True



# For the time/lat monsoon plot.
#lonm_w = 70 ; lonm_e = 100.
#latm_s = 0.; latm_n = 40. 

lonm_w = 70 ; lonm_e = 85.
latm_s = 10.; latm_n = 35. 

# Border of region for displayin map.
moffset = 10.

# Annual cycle options.
lat_lon = lonm_w,lonm_e,latm_s,latm_n



# Some run names
#crnums = ['001','002','003','004','005','006','007','008','009','010']
#crnums = ['001','002','003','004','005']
crnums = ['001']

#ernums =  ['0101','0151','0201','0251','0301']
ernums =  ['0101']

### TEMP PLOT ###

# %%
## Directories

dir_obs = '/glade/cesm/amwg/amwg_data/obs_data/'
dir_e3sm = '/glade/campaign/cgd/ccr/E3SMv2/FV_regridded/'
dir_cesm2 = '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1/'
dir_cesm1 = '/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily'
dir_o = '/glade/work/rneale/data/'


'''
    Ensmble set dic
'''

# Set ensebles set dic and df.

rset_dic = {}
rset_dic['E3SMv2'] = [dir_e3sm, ernums,'v2.FV1.historical_',years,'b','-',1.5]
#rset_dic['E3SM'] = [dir_e3sm, ernums,'v2.FV1.historical_',years,'b','-',1.5]
rset_dic['CESM2'] =  [dir_cesm2,crnums,'b.e21.BHISTcmip6.f09_g17.LE2-1251.',years,'g','-',1.5]
rset_dic['CESM1'] =  [dir_cesm1,crnums,'b.e11.B20TRC5CNBDRD.f09_g16.',years,'r','-',1.5]
rset_dic['GPCP'] =  [dir_o,[''],'GPCP',years,'k','--',4]
rset_dic['TRMM'] =  [dir_o,[''],'TRMM',["2000","2009"],'k',':',4]
rset_dic['AIR'] =  [dir_o,[''],'AIR',years,'k','-.',4]



#Dataframe
rset_df = pd.DataFrame.from_dict(rset_dic, orient='index',
            columns=['ens_dir','ens_rnums','ens_pref','ens_years','p_linecol','p_ldash','p_lthick'])

leg_cols = rset_df.loc[case_names]['p_linecol'] 
leg_dash = rset_df.loc[case_names]['p_ldash'] 
#leg_lwidth =  rset_df.loc[case_names]['p_lthick']                  
leg_lines = [Line2D([0], [0], color=col, linewidth=4, linestyle=leg_dash[ic]) for ic,col in enumerate(leg_cols)]


'''
    Variable dic.     
'''

var_dic = {}
var_dic['PRECT'] = (vscale,lat_lon,['GPCP','TRMM','AIR'],['PREC','PRECT',''],[1.,1.,1.])
                          
# Dataframe                                                    
var_df = pd.DataFrame.from_dict(var_dic, orient='index', columns=['vscale','lon_lat','osource','onames','oscale'])                 

scolors = ['black','black','black','lightblue','lightgreen','lightcoral']
# Out:
# /glade/derecho/scratch/rneale/tmp/ipykernel_55161/610034726.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   leg_lines = [Line2D([0], [0], color=col, linewidth=4, linestyle=leg_dash[ic]) for ic,col in enumerate(leg_cols)]

# %%
importlib.reload(myplt) # Required because I am constantly editing scam_func.py

fig, ax = mp.subplots(figsize=(20,12))
#ax = fig.add_axes([0.15,0.35,0.15,0.2],)
axins = myplt.region_mask(ax,lat_lon,lmask=True)

land_10m = NaturalEarthFeature('physical', 'land', '10m')
print(land_10m)

print(' ---------- Variable = '+var_name+' -----------')

for icase,cname in enumerate(case_names):
    
    nens = len(rset_df.loc[cname]['ens_rnums']) # Num. Ensmble simulations
    
    print('')
    print('**************************************************************')
    print('* Ensemble set #',icase+1,' (',cname,') - ',nens,' ensemble simulations')
    print('* Asking for years ',years[0],' to ',years[1])
    print('**************************************************************')
          
    rset = rset_df.loc[cname]   
    
        
    '''
        Routine for reading in data and calculating annual cycle from daily data
    '''
    
    # %time var_data = myplt.calc_daily_acycle(reg_name,cname,rset_df,var_df) # rest dic and ens index   

    
    '''
        Line plotting 
    '''
    
    linecol = rset_df.loc[cname]['p_linecol']    
    ldash = rset_df.loc[cname]['p_ldash']    
    lthick = rset_df.loc[cname]['p_lthick']    
    porder = 5 if cname in var_df.loc[var_name]['osource'] else 1
    
    
   
    #%time for iens in range(0,nens) : ax.plot(var_data[iens,:],color=linecol,linestyle=ldash,linewidth=lthick,zorder=porder)
    # %time for iens in range(0,nens) : ax.plot(var_data.mean(dim="ens_num"),color=linecol,linestyle=ldash,linewidth=lthick,zorder=porder)
    
    if cname not in ['TRMM','GPCP']:
        ax.fill_between(var_data.dayofyear, var_data.min(dim="ens_num"), var_data.max(dim="ens_num"), color=scolors[icase], alpha=.2)
    
    
'''
    Set Axes And Legend
'''

date_form = DateFormatter("%b")

ax.xaxis.set_major_locator(MonthLocator(bymonthday=15))
ax.xaxis.set_minor_locator(MonthLocator())
ax.xaxis.set_major_formatter(date_form)

ax.set_xlim([1,365]) 
yr = ax.get_ylim()
ax.vlines(153, yr[0], yr[1], color='black', linestyle='-') # Jun 2
ax.vlines(273, yr[0], yr[1], color='black', linestyle='-') # Spe 30

ax.text(156, 0, "June 2", rotation=90, verticalalignment='bottom',fontsize=20)
ax.text(276, 0, "September 30", rotation=90, verticalalignment='bottom',fontsize=20)

ax.tick_params(which='major', length=0)
ax.tick_params(which='minor', length=5)
ax.set_xlabel('Month', fontsize=18)
ax.set_ylabel('Cumulative Precipitation (mm)', fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)




ax.legend(leg_lines, case_names,loc='upper left',fontsize=22)
mp.savefig('daily_prec_as_AIR_cesm_e3sm_test.png', dpi=70)
# Out:
# /glade/work/rneale/python/miniconda3/envs/neale_vproc/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:395: UserWarning: The `map_projection` keyword argument is deprecated, use `projection` to instantiate a GeoAxes instead.
#   warnings.warn("The `map_projection` keyword argument is "
# <cartopy.feature.NaturalEarthFeature object at 0x150d1d842c80>
#  ---------- Variable = PRECT -----------
#
# **************************************************************
# * Ensemble set # 1  ( AIR ) -  1  ensemble simulations
# * Asking for years  1996  to  2005
# **************************************************************
# AIR  -  1  ensemble members
#
# - Ensemble run #  1
# -- return_common_loc -- : Grabbing typical run path for AIR
# /glade/work/rneale/data//AIR/AIR_daily_climatology.dat
# ['/glade/work/rneale/data//AIR/AIR_daily_climatology.dat']
# -Dataset year Range = 19XX to 20XX
# <xarray.DataArray (ens_num: 1, dayofyear: 365)> Size: 3kB
# array([[6.60000e-01, 1.07000e+00, 1.35000e+00, 1.75000e+00, 2.17000e+00,
#         2.72000e+00, 3.30000e+00, 3.89000e+00, 4.25000e+00, 4.65000e+00,
#         5.16000e+00, 5.61000e+00, 6.00000e+00, 6.65000e+00, 7.52000e+00,
#         8.24000e+00, 8.73000e+00, 9.22000e+00, 9.65000e+00, 9.97000e+00,
#         1.04900e+01, 1.10100e+01, 1.14600e+01, 1.18300e+01, 1.23700e+01,
#         1.29700e+01, 1.37600e+01, 1.43900e+01, 1.48900e+01, 1.53800e+01,
#         1.58700e+01, 1.63100e+01, 1.67300e+01, 1.72800e+01, 1.78800e+01,
#         1.85000e+01, 1.93400e+01, 2.02700e+01, 2.11600e+01, 2.19400e+01,
#         2.27500e+01, 2.35500e+01, 2.43400e+01, 2.53200e+01, 2.63000e+01,
#         2.71900e+01, 2.81100e+01, 2.90900e+01, 3.00600e+01, 3.08800e+01,
#         3.16100e+01, 3.23100e+01, 3.29300e+01, 3.37400e+01, 3.48300e+01,
#         3.58000e+01, 3.67800e+01, 3.77900e+01, 3.87600e+01, 3.98800e+01,
#         4.08300e+01, 4.14500e+01, 4.21300e+01, 4.29400e+01, 4.36200e+01,
#         4.41800e+01, 4.48900e+01, 4.58200e+01, 4.68900e+01, 4.80200e+01,
#         4.92700e+01, 5.02600e+01, 5.12200e+01, 5.22100e+01, 5.30900e+01,
#         5.40200e+01, 5.50500e+01, 5.61700e+01, 5.72200e+01, 5.83300e+01,
#         5.95400e+01, 6.06300e+01, 6.18200e+01, 6.29500e+01, 6.39300e+01,
#         6.48000e+01, 6.58100e+01, 6.69000e+01, 6.78700e+01, 6.89300e+01,
#         7.01600e+01, 7.13900e+01, 7.26400e+01, 7.38300e+01, 7.49100e+01,
#         7.63000e+01, 7.74700e+01, 7.88800e+01, 8.03200e+01, 8.14800e+01,
# ...
#         1.00366e+03, 1.00875e+03, 1.01341e+03, 1.01758e+03, 1.02150e+03,
#         1.02514e+03, 1.02877e+03, 1.03193e+03, 1.03515e+03, 1.03854e+03,
#         1.04204e+03, 1.04564e+03, 1.04920e+03, 1.05235e+03, 1.05568e+03,
#         1.05903e+03, 1.06207e+03, 1.06468e+03, 1.06705e+03, 1.06940e+03,
#         1.07170e+03, 1.07391e+03, 1.07613e+03, 1.07824e+03, 1.08044e+03,
#         1.08259e+03, 1.08466e+03, 1.08659e+03, 1.08834e+03, 1.09000e+03,
#         1.09167e+03, 1.09317e+03, 1.09467e+03, 1.09609e+03, 1.09734e+03,
#         1.09876e+03, 1.10028e+03, 1.10157e+03, 1.10280e+03, 1.10414e+03,
#         1.10559e+03, 1.10704e+03, 1.10823e+03, 1.10934e+03, 1.11044e+03,
#         1.11171e+03, 1.11306e+03, 1.11434e+03, 1.11522e+03, 1.11611e+03,
#         1.11706e+03, 1.11784e+03, 1.11880e+03, 1.11997e+03, 1.12101e+03,
#         1.12190e+03, 1.12258e+03, 1.12313e+03, 1.12362e+03, 1.12421e+03,
#         1.12496e+03, 1.12561e+03, 1.12611e+03, 1.12653e+03, 1.12702e+03,
#         1.12758e+03, 1.12806e+03, 1.12859e+03, 1.12911e+03, 1.12964e+03,
#         1.13011e+03, 1.13056e+03, 1.13105e+03, 1.13150e+03, 1.13194e+03,
#         1.13240e+03, 1.13304e+03, 1.13359e+03, 1.13416e+03, 1.13478e+03,
#         1.13550e+03, 1.13629e+03, 1.13680e+03, 1.13722e+03, 1.13756e+03,
#         1.13799e+03, 1.13844e+03, 1.13881e+03, 1.13912e+03, 1.13952e+03,
#         1.14006e+03, 1.14045e+03, 1.14094e+03, 1.14141e+03, 1.14186e+03,
#         1.14230e+03, 1.14279e+03, 1.14319e+03, 1.14366e+03, 1.14430e+03]])
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
# Dimensions without coordinates: ens_num
#
# CPU times: user 6.7 ms, sys: 0 ns, total: 6.7 ms
# Wall time: 6.64 ms
# <xarray.DataArray (ens_num: 1, dayofyear: 365)> Size: 3kB
# array([[6.60000e-01, 1.07000e+00, 1.35000e+00, 1.75000e+00, 2.17000e+00,
#         2.72000e+00, 3.30000e+00, 3.89000e+00, 4.25000e+00, 4.65000e+00,
#         5.16000e+00, 5.61000e+00, 6.00000e+00, 6.65000e+00, 7.52000e+00,
#         8.24000e+00, 8.73000e+00, 9.22000e+00, 9.65000e+00, 9.97000e+00,
#         1.04900e+01, 1.10100e+01, 1.14600e+01, 1.18300e+01, 1.23700e+01,
#         1.29700e+01, 1.37600e+01, 1.43900e+01, 1.48900e+01, 1.53800e+01,
#         1.58700e+01, 1.63100e+01, 1.67300e+01, 1.72800e+01, 1.78800e+01,
#         1.85000e+01, 1.93400e+01, 2.02700e+01, 2.11600e+01, 2.19400e+01,
#         2.27500e+01, 2.35500e+01, 2.43400e+01, 2.53200e+01, 2.63000e+01,
#         2.71900e+01, 2.81100e+01, 2.90900e+01, 3.00600e+01, 3.08800e+01,
#         3.16100e+01, 3.23100e+01, 3.29300e+01, 3.37400e+01, 3.48300e+01,
#         3.58000e+01, 3.67800e+01, 3.77900e+01, 3.87600e+01, 3.98800e+01,
#         4.08300e+01, 4.14500e+01, 4.21300e+01, 4.29400e+01, 4.36200e+01,
#         4.41800e+01, 4.48900e+01, 4.58200e+01, 4.68900e+01, 4.80200e+01,
#         4.92700e+01, 5.02600e+01, 5.12200e+01, 5.22100e+01, 5.30900e+01,
#         5.40200e+01, 5.50500e+01, 5.61700e+01, 5.72200e+01, 5.83300e+01,
#         5.95400e+01, 6.06300e+01, 6.18200e+01, 6.29500e+01, 6.39300e+01,
#         6.48000e+01, 6.58100e+01, 6.69000e+01, 6.78700e+01, 6.89300e+01,
#         7.01600e+01, 7.13900e+01, 7.26400e+01, 7.38300e+01, 7.49100e+01,
#         7.63000e+01, 7.74700e+01, 7.88800e+01, 8.03200e+01, 8.14800e+01,
# ...
#         1.00366e+03, 1.00875e+03, 1.01341e+03, 1.01758e+03, 1.02150e+03,
#         1.02514e+03, 1.02877e+03, 1.03193e+03, 1.03515e+03, 1.03854e+03,
#         1.04204e+03, 1.04564e+03, 1.04920e+03, 1.05235e+03, 1.05568e+03,
#         1.05903e+03, 1.06207e+03, 1.06468e+03, 1.06705e+03, 1.06940e+03,
#         1.07170e+03, 1.07391e+03, 1.07613e+03, 1.07824e+03, 1.08044e+03,
#         1.08259e+03, 1.08466e+03, 1.08659e+03, 1.08834e+03, 1.09000e+03,
#         1.09167e+03, 1.09317e+03, 1.09467e+03, 1.09609e+03, 1.09734e+03,
#         1.09876e+03, 1.10028e+03, 1.10157e+03, 1.10280e+03, 1.10414e+03,
#         1.10559e+03, 1.10704e+03, 1.10823e+03, 1.10934e+03, 1.11044e+03,
#         1.11171e+03, 1.11306e+03, 1.11434e+03, 1.11522e+03, 1.11611e+03,
#         1.11706e+03, 1.11784e+03, 1.11880e+03, 1.11997e+03, 1.12101e+03,
#         1.12190e+03, 1.12258e+03, 1.12313e+03, 1.12362e+03, 1.12421e+03,
#         1.12496e+03, 1.12561e+03, 1.12611e+03, 1.12653e+03, 1.12702e+03,
#         1.12758e+03, 1.12806e+03, 1.12859e+03, 1.12911e+03, 1.12964e+03,
#         1.13011e+03, 1.13056e+03, 1.13105e+03, 1.13150e+03, 1.13194e+03,
#         1.13240e+03, 1.13304e+03, 1.13359e+03, 1.13416e+03, 1.13478e+03,
#         1.13550e+03, 1.13629e+03, 1.13680e+03, 1.13722e+03, 1.13756e+03,
#         1.13799e+03, 1.13844e+03, 1.13881e+03, 1.13912e+03, 1.13952e+03,
#         1.14006e+03, 1.14045e+03, 1.14094e+03, 1.14141e+03, 1.14186e+03,
#         1.14230e+03, 1.14279e+03, 1.14319e+03, 1.14366e+03, 1.14430e+03]])
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
# Dimensions without coordinates: ens_num
# CPU times: user 1.22 ms, sys: 0 ns, total: 1.22 ms
# Wall time: 1.19 ms
#
# **************************************************************
# * Ensemble set # 2  ( TRMM ) -  1  ensemble simulations
# * Asking for years  1996  to  2005
# **************************************************************
# TRMM  -  1  ensemble members
#
# - Ensemble run #  1
# -- return_common_loc -- : Grabbing typical run path for TRMM
# /glade/work/rneale/data//TRMM/TRMM.PRECT.nc
# ['/glade/work/rneale/data//TRMM/TRMM.PRECT.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 4383)> Size: 35kB
# array([1998, 1998, 1998, ..., 2009, 2009, 2009])
# Coordinates:
#   * time     (time) datetime64[ns] 35kB 1998-01-01 1998-01-02 ... 2009-12-31
# Attributes:
#     info:     refers to the 00Z for the day  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1998)
# Coordinates:
#     time     datetime64[ns] 8B 1998-01-01
# Attributes:
#     info:     refers to the 00Z for the day
# Mask Generated for  TRMM
# <xarray.DataArray 'PRECT' (ens_num: 1, dayofyear: 366)> Size: 1kB
# dask.array<broadcast_to, shape=(1, 366), dtype=float32, chunksize=(1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 361 362 363 364 365 366
# Dimensions without coordinates: ens_num
#
# CPU times: user 1.21 s, sys: 52.1 ms, total: 1.26 s
# Wall time: 1.58 s
# <xarray.DataArray 'PRECT' (ens_num: 1, dayofyear: 366)> Size: 1kB
# dask.array<broadcast_to, shape=(1, 366), dtype=float32, chunksize=(1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 361 362 363 364 365 366
# Dimensions without coordinates: ens_num
# CPU times: user 4.13 s, sys: 234 ms, total: 4.37 s
# Wall time: 33.8 s
#
# **************************************************************
# * Ensemble set # 3  ( GPCP ) -  1  ensemble simulations
# * Asking for years  1996  to  2005
# **************************************************************
# GPCP  -  1  ensemble members
#
# - Ensemble run #  1
# -- return_common_loc -- : Grabbing typical run path for GPCP
# /glade/work/rneale/data//GPCP/GPCP_1DD_v1.2_199610-201407.nc
# ['/glade/work/rneale/data//GPCP/GPCP_1DD_v1.2_199610-201407.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 6513)> Size: 52kB
# array([1996, 1996, 1996, ..., 2014, 2014, 2014])
# Coordinates:
#   * time     (time) datetime64[ns] 52kB 1996-10-01T12:00:00 ... 2014-07-31T12...
# Attributes:
#     long_name:  time  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1996)
# Coordinates:
#     time     datetime64[ns] 8B 1996-10-01T12:00:00
# Attributes:
#     long_name:  time
# Mask Generated for  GPCP
# <xarray.DataArray 'PREC' (ens_num: 1, dayofyear: 366)> Size: 1kB
# dask.array<broadcast_to, shape=(1, 366), dtype=float32, chunksize=(1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 361 362 363 364 365 366
# Dimensions without coordinates: ens_num
#
# CPU times: user 1.35 s, sys: 91.3 ms, total: 1.44 s
# Wall time: 3.02 s
# <xarray.DataArray 'PREC' (ens_num: 1, dayofyear: 366)> Size: 1kB
# dask.array<broadcast_to, shape=(1, 366), dtype=float32, chunksize=(1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 361 362 363 364 365 366
# Dimensions without coordinates: ens_num
# CPU times: user 3.02 s, sys: 188 ms, total: 3.21 s
# Wall time: 9.43 s
#
# **************************************************************
# * Ensemble set # 4  ( E3SMv2 ) -  5  ensemble simulations
# * Asking for years  1996  to  2005
# **************************************************************
# E3SMv2  -  5  ensemble members
#
# - Ensemble run #  1
# -- return_common_loc -- : Grabbing typical run path for E3SMv2
# /glade/campaign/cgd/ccr/E3SMv2/FV_regridded//v2.FV1.historical_0101/atm/proc/tseries/day_1/v2.FV1.historical_0101.eam.h1.PRECT.18500101-20141231.nc
# ['/glade/campaign/cgd/ccr/E3SMv2/FV_regridded//v2.FV1.historical_0101/atm/proc/tseries/day_1/v2.FV1.historical_0101.eam.h1.PRECT.18500101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  E3SMv2
#
# - Ensemble run #  2
# -- return_common_loc -- : Grabbing typical run path for E3SMv2
# /glade/campaign/cgd/ccr/E3SMv2/FV_regridded//v2.FV1.historical_0151/atm/proc/tseries/day_1/v2.FV1.historical_0151.eam.h1.PRECT.18500101-20141231.nc
# ['/glade/campaign/cgd/ccr/E3SMv2/FV_regridded//v2.FV1.historical_0151/atm/proc/tseries/day_1/v2.FV1.historical_0151.eam.h1.PRECT.18500101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  E3SMv2
#
# - Ensemble run #  3
# -- return_common_loc -- : Grabbing typical run path for E3SMv2
# /glade/campaign/cgd/ccr/E3SMv2/FV_regridded//v2.FV1.historical_0201/atm/proc/tseries/day_1/v2.FV1.historical_0201.eam.h1.PRECT.18500101-20141231.nc
# ['/glade/campaign/cgd/ccr/E3SMv2/FV_regridded//v2.FV1.historical_0201/atm/proc/tseries/day_1/v2.FV1.historical_0201.eam.h1.PRECT.18500101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  E3SMv2
#
# - Ensemble run #  4
# -- return_common_loc -- : Grabbing typical run path for E3SMv2
# /glade/campaign/cgd/ccr/E3SMv2/FV_regridded//v2.FV1.historical_0251/atm/proc/tseries/day_1/v2.FV1.historical_0251.eam.h1.PRECT.18500101-20141231.nc
# ['/glade/campaign/cgd/ccr/E3SMv2/FV_regridded//v2.FV1.historical_0251/atm/proc/tseries/day_1/v2.FV1.historical_0251.eam.h1.PRECT.18500101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  E3SMv2
#
# - Ensemble run #  5
# -- return_common_loc -- : Grabbing typical run path for E3SMv2
# /glade/campaign/cgd/ccr/E3SMv2/FV_regridded//v2.FV1.historical_0301/atm/proc/tseries/day_1/v2.FV1.historical_0301.eam.h1.PRECT.18500101-20141231.nc
# ['/glade/campaign/cgd/ccr/E3SMv2/FV_regridded//v2.FV1.historical_0301/atm/proc/tseries/day_1/v2.FV1.historical_0301.eam.h1.PRECT.18500101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  E3SMv2
# <xarray.DataArray 'PRECT' (ens_num: 5, dayofyear: 365)> Size: 7kB
# array([[1.2954779e+00, 2.4453933e+00, 3.6606562e+00, ..., 8.8970569e+02,
#         8.9055847e+02, 8.9181744e+02],
#        [7.2491682e-01, 1.6353970e+00, 2.6621718e+00, ..., 9.9767529e+02,
#         9.9868024e+02, 9.9952740e+02],
#        [2.1843431e+00, 3.8171096e+00, 5.2636900e+00, ..., 9.6185248e+02,
#         9.6354309e+02, 9.6529199e+02],
#        [1.3376396e+00, 2.3181300e+00, 3.2267077e+00, ..., 8.2672449e+02,
#         8.2841858e+02, 8.2957495e+02],
#        [1.4322050e+00, 3.8716702e+00, 6.7108917e+00, ..., 9.8072229e+02,
#         9.8242328e+02, 9.8386505e+02]], dtype=float32)
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
# Dimensions without coordinates: ens_num
#
# CPU times: user 2min 4s, sys: 4.37 s, total: 2min 8s
# Wall time: 2min 12s
# <xarray.DataArray 'PRECT' (ens_num: 5, dayofyear: 365)> Size: 7kB
# array([[1.2954779e+00, 2.4453933e+00, 3.6606562e+00, ..., 8.8970569e+02,
#         8.9055847e+02, 8.9181744e+02],
#        [7.2491682e-01, 1.6353970e+00, 2.6621718e+00, ..., 9.9767529e+02,
#         9.9868024e+02, 9.9952740e+02],
#        [2.1843431e+00, 3.8171096e+00, 5.2636900e+00, ..., 9.6185248e+02,
#         9.6354309e+02, 9.6529199e+02],
#        [1.3376396e+00, 2.3181300e+00, 3.2267077e+00, ..., 8.2672449e+02,
#         8.2841858e+02, 8.2957495e+02],
#        [1.4322050e+00, 3.8716702e+00, 6.7108917e+00, ..., 9.8072229e+02,
#         9.8242328e+02, 9.8386505e+02]], dtype=float32)
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
# Dimensions without coordinates: ens_num
# CPU times: user 8.84 ms, sys: 76 μs, total: 8.92 ms
# Wall time: 8.54 ms
#
# **************************************************************
# * Ensemble set # 5  ( CESM2 ) -  10  ensemble simulations
# * Asking for years  1996  to  2005
# **************************************************************
# CESM2  -  10  ensemble members
#
# - Ensemble run #  1
# -- return_common_loc -- : Grabbing typical run path for CESM2
# /glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.*.nc
# ['/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.18500101-18591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.18600101-18691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.18700101-18791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.18800101-18891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.18900101-18991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.19000101-19091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.19100101-19191231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.19200101-19291231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.19300101-19391231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.19400101-19491231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.19500101-19591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.19600101-19691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.19700101-19791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.19800101-19891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.19900101-19991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.20000101-20091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.001.cam.h1.PRECT.20100101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM2
#
# - Ensemble run #  2
# -- return_common_loc -- : Grabbing typical run path for CESM2
# /glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.*.nc
# ['/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.18500101-18591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.18600101-18691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.18700101-18791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.18800101-18891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.18900101-18991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.19000101-19091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.19100101-19191231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.19200101-19291231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.19300101-19391231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.19400101-19491231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.19500101-19591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.19600101-19691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.19700101-19791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.19800101-19891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.19900101-19991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.20000101-20091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.002.cam.h1.PRECT.20100101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM2
#
# - Ensemble run #  3
# -- return_common_loc -- : Grabbing typical run path for CESM2
# /glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.*.nc
# ['/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.18500101-18591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.18600101-18691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.18700101-18791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.18800101-18891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.18900101-18991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.19000101-19091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.19100101-19191231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.19200101-19291231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.19300101-19391231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.19400101-19491231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.19500101-19591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.19600101-19691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.19700101-19791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.19800101-19891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.19900101-19991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.20000101-20091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.003.cam.h1.PRECT.20100101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM2
#
# - Ensemble run #  4
# -- return_common_loc -- : Grabbing typical run path for CESM2
# /glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.*.nc
# ['/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.18500101-18591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.18600101-18691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.18700101-18791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.18800101-18891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.18900101-18991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.19000101-19091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.19100101-19191231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.19200101-19291231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.19300101-19391231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.19400101-19491231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.19500101-19591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.19600101-19691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.19700101-19791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.19800101-19891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.19900101-19991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.20000101-20091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.004.cam.h1.PRECT.20100101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM2
#
# - Ensemble run #  5
# -- return_common_loc -- : Grabbing typical run path for CESM2
# /glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.*.nc
# ['/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.18500101-18591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.18600101-18691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.18700101-18791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.18800101-18891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.18900101-18991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.19000101-19091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.19100101-19191231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.19200101-19291231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.19300101-19391231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.19400101-19491231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.19500101-19591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.19600101-19691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.19700101-19791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.19800101-19891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.19900101-19991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.20000101-20091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.005.cam.h1.PRECT.20100101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM2
#
# - Ensemble run #  6
# -- return_common_loc -- : Grabbing typical run path for CESM2
# /glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.*.nc
# ['/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.18500101-18591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.18600101-18691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.18700101-18791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.18800101-18891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.18900101-18991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.19000101-19091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.19100101-19191231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.19200101-19291231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.19300101-19391231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.19400101-19491231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.19500101-19591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.19600101-19691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.19700101-19791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.19800101-19891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.19900101-19991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.20000101-20091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.006.cam.h1.PRECT.20100101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM2
#
# - Ensemble run #  7
# -- return_common_loc -- : Grabbing typical run path for CESM2
# /glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.*.nc
# ['/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.18500101-18591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.18600101-18691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.18700101-18791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.18800101-18891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.18900101-18991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.19000101-19091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.19100101-19191231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.19200101-19291231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.19300101-19391231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.19400101-19491231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.19500101-19591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.19600101-19691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.19700101-19791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.19800101-19891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.19900101-19991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.20000101-20091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.007.cam.h1.PRECT.20100101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM2
#
# - Ensemble run #  8
# -- return_common_loc -- : Grabbing typical run path for CESM2
# /glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.*.nc
# ['/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.18500101-18591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.18600101-18691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.18700101-18791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.18800101-18891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.18900101-18991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.19000101-19091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.19100101-19191231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.19200101-19291231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.19300101-19391231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.19400101-19491231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.19500101-19591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.19600101-19691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.19700101-19791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.19800101-19891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.19900101-19991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.20000101-20091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.008.cam.h1.PRECT.20100101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM2
#
# - Ensemble run #  9
# -- return_common_loc -- : Grabbing typical run path for CESM2
# /glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.*.nc
# ['/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.18500101-18591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.18600101-18691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.18700101-18791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.18800101-18891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.18900101-18991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.19000101-19091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.19100101-19191231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.19200101-19291231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.19300101-19391231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.19400101-19491231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.19500101-19591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.19600101-19691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.19700101-19791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.19800101-19891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.19900101-19991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.20000101-20091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.009.cam.h1.PRECT.20100101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM2
#
# - Ensemble run #  10
# -- return_common_loc -- : Grabbing typical run path for CESM2
# /glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.*.nc
# ['/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.18500101-18591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.18600101-18691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.18700101-18791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.18800101-18891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.18900101-18991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.19000101-19091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.19100101-19191231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.19200101-19291231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.19300101-19391231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.19400101-19491231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.19500101-19591231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.19600101-19691231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.19700101-19791231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.19800101-19891231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.19900101-19991231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.20000101-20091231.nc', '/glade/campaign/cgd/cesm/CESM2-LE/atm/proc/tseries/day_1//PRECT/b.e21.BHISTcmip6.f09_g17.LE2-1251.010.cam.h1.PRECT.20100101-20141231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 60226)> Size: 482kB
# array([1850, 1850, 1850, ..., 2014, 2014, 2015])
# Coordinates:
#   * time     (time) object 482kB 1850-01-01 00:00:00 ... 2015-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM2
# <xarray.DataArray 'PRECT' (ens_num: 10, dayofyear: 365)> Size: 15kB
# array([[1.03760374e+00, 1.82760477e+00, 2.40656328e+00, ...,
#         1.00110718e+03, 1.00152686e+03, 1.00209387e+03],
#        [9.86298919e-01, 1.71632838e+00, 2.54031277e+00, ...,
#         9.95956116e+02, 9.96953308e+02, 9.98264038e+02],
#        [6.92481697e-01, 1.41938400e+00, 3.00887156e+00, ...,
#         8.91292236e+02, 8.92028870e+02, 8.92844360e+02],
#        ...,
#        [8.92793179e-01, 1.86592245e+00, 2.28766227e+00, ...,
#         1.06760400e+03, 1.06833618e+03, 1.06929517e+03],
#        [5.69448709e-01, 1.66565287e+00, 2.51227021e+00, ...,
#         9.67893982e+02, 9.68330505e+02, 9.68815063e+02],
#        [6.92466736e-01, 1.01276886e+00, 1.47856343e+00, ...,
#         9.61186462e+02, 9.61765015e+02, 9.62905945e+02]], dtype=float32)
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
# Dimensions without coordinates: ens_num
#
# CPU times: user 4min 36s, sys: 9.18 s, total: 4min 45s
# Wall time: 5min 8s
# <xarray.DataArray 'PRECT' (ens_num: 10, dayofyear: 365)> Size: 15kB
# array([[1.03760374e+00, 1.82760477e+00, 2.40656328e+00, ...,
#         1.00110718e+03, 1.00152686e+03, 1.00209387e+03],
#        [9.86298919e-01, 1.71632838e+00, 2.54031277e+00, ...,
#         9.95956116e+02, 9.96953308e+02, 9.98264038e+02],
#        [6.92481697e-01, 1.41938400e+00, 3.00887156e+00, ...,
#         8.91292236e+02, 8.92028870e+02, 8.92844360e+02],
#        ...,
#        [8.92793179e-01, 1.86592245e+00, 2.28766227e+00, ...,
#         1.06760400e+03, 1.06833618e+03, 1.06929517e+03],
#        [5.69448709e-01, 1.66565287e+00, 2.51227021e+00, ...,
#         9.67893982e+02, 9.68330505e+02, 9.68815063e+02],
#        [6.92466736e-01, 1.01276886e+00, 1.47856343e+00, ...,
#         9.61186462e+02, 9.61765015e+02, 9.62905945e+02]], dtype=float32)
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
# Dimensions without coordinates: ens_num
# CPU times: user 33.6 ms, sys: 120 μs, total: 33.7 ms
# Wall time: 32.5 ms
#
# **************************************************************
# * Ensemble set # 6  ( CESM1 ) -  10  ensemble simulations
# * Asking for years  1996  to  2005
# **************************************************************
# CESM1  -  10  ensemble members
#
# - Ensemble run #  1
# -- return_common_loc -- : Grabbing typical run path for CESM1
# /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h1.*.nc
# ['/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.001.cam.h1.PRECT.18500101-20051231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 56940)> Size: 456kB
# array([1850, 1850, 1850, ..., 2005, 2005, 2005])
# Coordinates:
#   * time     (time) object 456kB 1850-01-01 00:00:00 ... 2005-12-31 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1850)
# Coordinates:
#     time     object 8B 1850-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM1
#
# - Ensemble run #  2
# -- return_common_loc -- : Grabbing typical run path for CESM1
# /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h1.*.nc
# ['/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.002.cam.h1.PRECT.19200101-20051231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 31390)> Size: 251kB
# array([1920, 1920, 1920, ..., 2005, 2005, 2005])
# Coordinates:
#   * time     (time) object 251kB 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1920)
# Coordinates:
#     time     object 8B 1920-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM1
#
# - Ensemble run #  3
# -- return_common_loc -- : Grabbing typical run path for CESM1
# /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.003.cam.h1.*.nc
# ['/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.003.cam.h1.PRECT.19200101-20051231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 31390)> Size: 251kB
# array([1920, 1920, 1920, ..., 2005, 2005, 2005])
# Coordinates:
#   * time     (time) object 251kB 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1920)
# Coordinates:
#     time     object 8B 1920-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM1
#
# - Ensemble run #  4
# -- return_common_loc -- : Grabbing typical run path for CESM1
# /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.004.cam.h1.*.nc
# ['/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.004.cam.h1.PRECT.19200101-20051231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 31390)> Size: 251kB
# array([1920, 1920, 1920, ..., 2005, 2005, 2005])
# Coordinates:
#   * time     (time) object 251kB 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1920)
# Coordinates:
#     time     object 8B 1920-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM1
#
# - Ensemble run #  5
# -- return_common_loc -- : Grabbing typical run path for CESM1
# /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.005.cam.h1.*.nc
# ['/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.005.cam.h1.PRECT.19200101-20051231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 31390)> Size: 251kB
# array([1920, 1920, 1920, ..., 2005, 2005, 2005])
# Coordinates:
#   * time     (time) object 251kB 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1920)
# Coordinates:
#     time     object 8B 1920-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM1
#
# - Ensemble run #  6
# -- return_common_loc -- : Grabbing typical run path for CESM1
# /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.006.cam.h1.*.nc
# ['/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.006.cam.h1.PRECT.19200101-20051231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 31390)> Size: 251kB
# array([1920, 1920, 1920, ..., 2005, 2005, 2005])
# Coordinates:
#   * time     (time) object 251kB 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1920)
# Coordinates:
#     time     object 8B 1920-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM1
#
# - Ensemble run #  7
# -- return_common_loc -- : Grabbing typical run path for CESM1
# /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.007.cam.h1.*.nc
# ['/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.007.cam.h1.PRECT.19200101-20051231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 31390)> Size: 251kB
# array([1920, 1920, 1920, ..., 2005, 2005, 2005])
# Coordinates:
#   * time     (time) object 251kB 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1920)
# Coordinates:
#     time     object 8B 1920-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM1
#
# - Ensemble run #  8
# -- return_common_loc -- : Grabbing typical run path for CESM1
# /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.008.cam.h1.*.nc
# ['/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.008.cam.h1.PRECT.19200101-20051231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 31390)> Size: 251kB
# array([1920, 1920, 1920, ..., 2005, 2005, 2005])
# Coordinates:
#   * time     (time) object 251kB 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1920)
# Coordinates:
#     time     object 8B 1920-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM1
#
# - Ensemble run #  9
# -- return_common_loc -- : Grabbing typical run path for CESM1
# /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.009.cam.h1.*.nc
# ['/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.009.cam.h1.PRECT.19200101-20051231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 31390)> Size: 251kB
# array([1920, 1920, 1920, ..., 2005, 2005, 2005])
# Coordinates:
#   * time     (time) object 251kB 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1920)
# Coordinates:
#     time     object 8B 1920-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM1
#
# - Ensemble run #  10
# -- return_common_loc -- : Grabbing typical run path for CESM1
# /glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.010.cam.h1.*.nc
# ['/glade/campaign/cesm/collections/cesmLE/CESM-CAM5-BGC-LE/atm/proc/tseries/daily/PRECT/b.e11.B20TRC5CNBDRD.f09_g16.010.cam.h1.PRECT.19200101-20051231.nc']
# -Dataset year Range =  <xarray.DataArray 'year' (time: 31390)> Size: 251kB
# array([1920, 1920, 1920, ..., 2005, 2005, 2005])
# Coordinates:
#   * time     (time) object 251kB 1920-01-01 00:00:00 ... 2005-12-31 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds  to  <xarray.DataArray 'year' ()> Size: 8B
# array(1920)
# Coordinates:
#     time     object 8B 1920-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds
# Mask Generated for  CESM1
# <xarray.DataArray 'PRECT' (ens_num: 10, dayofyear: 365)> Size: 15kB
# array([[5.9687722e-01, 1.0906421e+00, 1.5876338e+00, ..., 1.2158005e+03,
#         1.2168939e+03, 1.2177203e+03],
#        [3.6417708e-01, 9.2623973e-01, 1.4263471e+00, ..., 1.1561515e+03,
#         1.1567372e+03, 1.1571213e+03],
#        [1.1652067e+00, 1.9678298e+00, 2.7305036e+00, ..., 1.1985195e+03,
#         1.1999895e+03, 1.2014548e+03],
#        ...,
#        [9.8799056e-01, 1.5599570e+00, 1.8487537e+00, ..., 1.2145913e+03,
#         1.2163121e+03, 1.2178658e+03],
#        [1.2725203e+00, 2.4847713e+00, 3.6806755e+00, ..., 1.2324861e+03,
#         1.2343353e+03, 1.2356390e+03],
#        [5.3373754e-01, 9.4027776e-01, 1.3486865e+00, ..., 1.1566837e+03,
#         1.1575212e+03, 1.1581146e+03]], dtype=float32)
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
# Dimensions without coordinates: ens_num
#
# CPU times: user 4min 33s, sys: 59 s, total: 5min 32s
# Wall time: 5min 29s
# <xarray.DataArray 'PRECT' (ens_num: 10, dayofyear: 365)> Size: 15kB
# array([[5.9687722e-01, 1.0906421e+00, 1.5876338e+00, ..., 1.2158005e+03,
#         1.2168939e+03, 1.2177203e+03],
#        [3.6417708e-01, 9.2623973e-01, 1.4263471e+00, ..., 1.1561515e+03,
#         1.1567372e+03, 1.1571213e+03],
#        [1.1652067e+00, 1.9678298e+00, 2.7305036e+00, ..., 1.1985195e+03,
#         1.1999895e+03, 1.2014548e+03],
#        ...,
#        [9.8799056e-01, 1.5599570e+00, 1.8487537e+00, ..., 1.2145913e+03,
#         1.2163121e+03, 1.2178658e+03],
#        [1.2725203e+00, 2.4847713e+00, 3.6806755e+00, ..., 1.2324861e+03,
#         1.2343353e+03, 1.2356390e+03],
#        [5.3373754e-01, 9.4027776e-01, 1.3486865e+00, ..., 1.1566837e+03,
#         1.1575212e+03, 1.1581146e+03]], dtype=float32)
# Coordinates:
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
# Dimensions without coordinates: ens_num
# CPU times: user 12.5 ms, sys: 64 μs, total: 12.6 ms
# Wall time: 11.7 ms
