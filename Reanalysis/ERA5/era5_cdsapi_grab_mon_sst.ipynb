# %% [markdown]
# ## Code to grab ERA5 data using cdsapi

# %%
import cdsapi

# %%
# These are here, but actually taken from ~/.cdsapirc
url = 'https://cds.climate.copernicus.eu/api/v2'
key: '98208:5398f2c2-bba0-472b-bc7e-8aa81b874a6d'

#dir_out  = '/glade/work/rneale/data/ERA5/from_cdsapi/'
dir_out = '/glade/derecho/scratch/rneale/ERA5/'

c = cdsapi.Client()

for iyr in range(1979,2024):

    c.retrieve(
        'reanalysis-era5-single-levels-monthly-means',
        {
            'product_type': 'monthly_averaged_reanalysis',
            'variable': 'total_precipitation',
            'year': [
                str(iyr),
            ],
            'month': [
                '01', '02', '03',
                '04', '05', '06',
                '07', '08', '09',
                '10', '11', '12'],
            
            'time': '00:00',
            
            'format': 'netcdf',
        },
        dir_out+'prect_test_era5_monthly_'+str(iyr)+'.nc')
# Out:
# 2024-05-28 05:50:25,654 INFO Welcome to the CDS
# 2024-05-28 05:50:25,657 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels-monthly-means
# 2024-05-28 05:50:26,026 INFO Request is queued
# 2024-05-28 05:51:42,177 INFO Request is running
# 2024-05-28 05:54:45,620 INFO Request is completed
# 2024-05-28 05:54:45,621 INFO Downloading https://download-0013-clone.copernicus-climate.eu/cache-compute-0013/cache/data5/adaptor.mars.internal-1716897203.5677295-21960-2-afae318f-6e69-4d68-af98-b52398f62735.nc to /glade/derecho/scratch/rneale/ERA5/prect_test_era5_monthly_1979.nc (23.8M)
# 2024-05-28 05:54:50,263 INFO Download rate 5.1M/s
# 2024-05-28 05:54:50,539 INFO Welcome to the CDS
# 2024-05-28 05:54:50,540 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels-monthly-means
# 2024-05-28 05:54:50,983 INFO Request is queued
# 2024-05-28 05:54:59,657 INFO Request is running
# 2024-05-28 05:57:43,492 INFO Request is completed
# 2024-05-28 05:57:43,493 INFO Downloading https://download-0005-clone.copernicus-climate.eu/cache-compute-0005/cache/data4/adaptor.mars.internal-1716897415.8327844-16274-15-4969e106-1e81-459c-93de-fb0b1a012384.nc to /glade/derecho/scratch/rneale/ERA5/prect_test_era5_monthly_1980.nc (23.8M)
# 2024-05-28 05:57:46,549 INFO Download rate 7.8M/s
# 2024-05-28 05:57:46,836 INFO Welcome to the CDS
# 2024-05-28 05:57:46,838 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels-monthly-means
# 2024-05-28 05:57:47,160 INFO Request is queued
# 2024-05-28 05:58:09,124 INFO Request is running
# 2024-05-28 06:00:40,446 INFO Request is completed
# 2024-05-28 06:00:40,447 INFO Downloading https://download-0018.copernicus-climate.eu/cache-compute-0018/cache/data9/adaptor.mars.internal-1716897589.9251955-1333-10-db5e0933-b21b-4e38-86d3-37f7165499ba.nc to /glade/derecho/scratch/rneale/ERA5/prect_test_era5_monthly_1981.nc (23.8M)
# 2024-05-28 06:00:43,216 INFO Download rate 8.6M/s
# 2024-05-28 06:00:43,489 INFO Welcome to the CDS
# 2024-05-28 06:00:43,491 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels-monthly-means
# 2024-05-28 06:00:43,768 INFO Request is queued
# 2024-05-28 06:01:34,128 INFO Request is running
# 2024-05-28 06:03:36,278 INFO Request is completed
# 2024-05-28 06:03:36,279 INFO Downloading https://download-0020.copernicus-climate.eu/cache-compute-0020/cache/data8/adaptor.mars.internal-1716897794.8606029-5303-11-5b60777c-d548-43b0-a0f8-e77fd1aefc8a.nc to /glade/derecho/scratch/rneale/ERA5/prect_test_era5_monthly_1982.nc (23.8M)
# 2024-05-28 06:03:39,171 INFO Download rate 8.2M/s
# 2024-05-28 06:03:39,446 INFO Welcome to the CDS
# 2024-05-28 06:03:39,447 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels-monthly-means
# 2024-05-28 06:03:39,824 INFO Request is queued

# %%
'''
    Line below works for cdsapi
'''


#c.retrieve('reanalysis-era5-complete', { # Requests follow MARS syntax
#                                            # Keywords 'expver' and 'class' can be dropped. They are obsolete
#                                            # since their values are imposed by 'reanalysis-era5-complete'
#       'date'    : '2013-01-01',            # The hyphens can be omitted
#       'levelist': '1/10/100/137',          # 1 is top level, 137 the lowest model level in ERA5. Use '/' to separate values.
#       'levtype' : 'ml',
#       'param'   : '130',                   # Full information at https://apps.ecmwf.int/codes/grib/param-db/
#                                            # The native representation for temperature is spherical harmonics
#       'stream'  : 'oper',                  # Denotes ERA5. Ensemble members are selected by 'enda'
#       'time'    : '00/to/23/by/6',         # You can drop :00:00 and use MARS short-hand notation, instead of '00/06/12/18'
#       'type'    : 'an',
#       'area'    : '80/-50/-25/0',          # North, West, South, East. Default: global
#       'grid'    : '1.0/1.0',               # Latitude/longitude. Default: spherical harmonics or reduced Gaussian grid
#       'format'  : 'netcdf',                # Output needs to be regular lat-lon, so only works in combination with 'grid'!
#   }, 'ERA5-ml-temperature-subarea.nc')     # Output file. Adapt as you wish.
