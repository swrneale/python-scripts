# %%
import xarray as xr

# %%
vdir = '/glade/scratch/rneale/ERA5/'
vfile = 'lhflx_test_era5_download_1999_test.nc'

var_in = xr.open_dataset(vdir+vfile)

# %%
var_in
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 8760, longitude: 1440, latitude: 721)
# Coordinates:
#   * time       (time) datetime64[ns] 1999-01-01 ... 1999-12-31T23:00:00
#   * longitude  (longitude) float32 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
# Data variables:
#     slhf1      (time, latitude, longitude) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.2.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Thu Nov 09 12:02:56 2023: cdo -expr,slhf1=1.0*slhf lhflx_te...
#     CDO:          Climate Data Operators version 2.2.2 (https://mpimet.mpg.de...

# %%
var_in.max()
