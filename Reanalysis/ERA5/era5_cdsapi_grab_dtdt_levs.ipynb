# %% [markdown]
# ## Code to grab ERA5 data suinsg cdsapi

# %%
import cdsapi

# %%
# These are here, but actually taken from ~/.cdsapirc
url = 'https://cds.climate.copernicus.eu/api/v2'
key: '98208:5398f2c2-bba0-472b-bc7e-8aa81b874a6d'

#dir_out  = '/glade/work/rneale/data/ERA5/from_cdsapi/'
dir_out = '/glade/scratch/rneale/ERA5/'

c = cdsapi.Client()

var_3d = 'dtdt_conv'  ; var_3d_name = 'tendency_of_air_temperature_due_to_convective_heating'


for iyr in range(1979,1980):

    c.retrieve(
        'reanalysis-era5-monthly-means',
        {
            'product_type': 'monthly_averaged_reanalysis',
            'variable': var_3d_name,
            "pressure_level": '1000',
            'year': [
                str(iyr),
            ],
            'month': [
                '01', '02', '03',
                '04', '05', '06',
                '07', '08', '09',
                '10', '11', '12',
            ],
             'time': '00:00',
            
            'format': 'netcdf',
        },
        dir_out+var_3d+'_test_era5_monthly_'+str(iyr)+'.nc')
# Out:
# 2024-06-23 14:05:34,096 INFO Welcome to the CDS
# 2024-06-23 14:05:34,097 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-monthly-means
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /glade/work/rneale/python/miniconda3/envs/era5_grab/lib/python3.12/site-packages/cdsapi/api.py:442, in Client._api(self, url, request, method)
#     441 try:
# --> 442     result.raise_for_status()
#     443     reply = result.json()
#
# File /glade/work/rneale/python/miniconda3/envs/era5_grab/lib/python3.12/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error:  for url: https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-monthly-means
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 15
#      10 var_3d = 'dtdt_conv'  ; var_3d_name = 'tendency_of_air_temperature_due_to_convective_heating'
#      13 for iyr in range(1979,1980):
# ---> 15     c.retrieve(
#      16         'reanalysis-era5-monthly-means',
#      17         {
#      18             'product_type': 'monthly_averaged_reanalysis',
#      19             'variable': var_3d_name,
#      20             "pressure_level": '1000',
#      21             'year': [
#      22                 str(iyr),
#      23             ],
#      24             'month': [
#      25                 '01', '02', '03',
#      26                 '04', '05', '06',
#      27                 '07', '08', '09',
#      28                 '10', '11', '12',
#      29             ],
#      30              'time': '00:00',
#      31
#      32             'format': 'netcdf',
#      33         },
#      34         dir_out+var_3d+'_test_era5_download_'+str(iyr)+'.nc')
#
# File /glade/work/rneale/python/miniconda3/envs/era5_grab/lib/python3.12/site-packages/cdsapi/api.py:364, in Client.retrieve(self, name, request, target)
#     363 def retrieve(self, name, request, target=None):
# --> 364     result = self._api("%s/resources/%s" % (self.url, name), request, "POST")
#     365     if target is not None:
#     366         result.download(target)
#
# File /glade/work/rneale/python/miniconda3/envs/era5_grab/lib/python3.12/site-packages/cdsapi/api.py:464, in Client._api(self, url, request, method)
#     459             e.append(
#     460                 "To access this resource, you first need to accept the terms"
#     461                 "of '%s' at %s" % (t["title"], t["url"])
#     462             )
#     463         error = ". ".join(e)
# --> 464     raise Exception(error)
#     465 else:
#     466     raise
#
# Exception: Resource reanalysis-era5-monthly-means not found

# %%
'''
    Line below works for cdsapi
'''


#c.retrieve('reanalysis-era5-complete', { # Requests follow MARS syntax
#                                            # Keywords 'expver' and 'class' can be dropped. They are obsolete
#                                            # since their values are imposed by 'reanalysis-era5-complete'
#       'date'    : '2013-01-01',            # The hyphens can be omitted
#       'levelist': '1/10/100/137',          # 1 is top level, 137 the lowest model level in ERA5. Use '/' to separate values.
#       'levtype' : 'ml',
#       'param'   : '130',                   # Full information at https://apps.ecmwf.int/codes/grib/param-db/
#                                            # The native representation for temperature is spherical harmonics
#       'stream'  : 'oper',                  # Denotes ERA5. Ensemble members are selected by 'enda'
#       'time'    : '00/to/23/by/6',         # You can drop :00:00 and use MARS short-hand notation, instead of '00/06/12/18'
#       'type'    : 'an',
#       'area'    : '80/-50/-25/0',          # North, West, South, East. Default: global
#       'grid'    : '1.0/1.0',               # Latitude/longitude. Default: spherical harmonics or reduced Gaussian grid
#       'format'  : 'netcdf',                # Output needs to be regular lat-lon, so only works in combination with 'grid'!
#   }, 'ERA5-ml-temperature-subarea.nc')     # Output file. Adapt as you wish.
