# %%
import cdsapi

# %%
client = cdsapi.Client()

dataset = 'reanalysis-era5-pressure-levels'
request = {
  'product_type': ['reanalysis'],
  'variable': ['geopotential'],
  'year': ['2024'],
  'month': ['03'],
  'day': ['01'],
  'time': ['13:00'],
  'pressure_level': ['1000'],
  'data_format': 'grib',
}
target = 'download.grib'

client.retrieve(dataset, request, target)
# Out:
# 2025-07-02 09:00:17,456 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2025-07-02 09:00:17,841 INFO Request ID is 1de68712-f508-4f45-a65e-e335d016cf61
# 2025-07-02 09:00:18,017 INFO status has been updated to accepted
# 2025-07-02 09:00:32,233 INFO status has been updated to successful
# 'download.grib'
