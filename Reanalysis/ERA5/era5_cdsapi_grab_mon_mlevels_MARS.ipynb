# %% [markdown]
# ## Code to grab ERA5 data using cdsapi

# %%
import cdsapi
import numpy as np

# %%
# Script to download on model levels


# These are here, but actually taken from ~/.cdsapirc
url = 'https://cds.climate.copernicus.eu/api/v2'
key: '98208:5398f2c2-bba0-472b-bc7e-8aa81b874a6d'

#dir_out  = '/glade/work/rneale/data/ERA5/from_cdsapi/'
dir_out = '/glade/derecho/scratch/rneale/ERA5/download/'


## Settings ##

do_cds = True

var_3d = 'dtdt_param'  ; param_num = '235005' ; var_3d_name = 'mean_temperature_tendency_due_to_parametrisations'

year0 = 1996
year1 = 2000

lev0 = 50
lev1 = 137


## Levels
levs_list = list(range(lev0,lev1+1))
levs_list = [str(i) for i in levs_list]
lev_list =  '/'.join(levs_list)

print('-levels = '+lev_list)



#######


years_list = list(range(year0, year1 + 1))

c = cdsapi.Client()

print()
print(' - DOWNLOADING -')

for yr in range(year0,year1+1):
    
    for month in range(1,13):

        print()
        
        date_list = generate_dates(yr,month)
        mfile_out =   dir_out+var_3d+'_'+str(yr)+'_'+str(f"{month:02d}")+'_ytest_era5_modelevs.grib' 
        print('-Ouput file '+mfile_out)
        
        if do_cds:
            c.retrieve("reanalysis-era5-complete", {
                "class": "ea",
                "date": date_list,
                "expver": "1",
                "levelist": lev_list,
                "levtype": "ml",
                "param": param_num,
                "step": "12",
                "stream": "oper",
                "time": "06:00:00/18:00:00",
                "type": "fc"},
                mfile_out )
# Out:
# -levels = 
#
#  - DOWNLOADING -
#
# -For year = 1991 and month = 1
# 1991-01-01/1991-01-02/1991-01-03/1991-01-04/1991-01-05/1991-01-06/1991-01-07/1991-01-08/1991-01-09/1991-01-10/1991-01-11/1991-01-12/1991-01-13/1991-01-14/1991-01-15/1991-01-16/1991-01-17/1991-01-18/1991-01-19/1991-01-20/1991-01-21/1991-01-22/1991-01-23/1991-01-24/1991-01-25/1991-01-26/1991-01-27/1991-01-28/1991-01-29/1991-01-30/1991-01-31
# -Ouput file /glade/derecho/scratch/rneale/ERA5/download/dtdt_param_1991_01_ytest_era5_modelevs.grib
# 2024-08-12 14:40:58,479 INFO Welcome to the CDS.
#  As per our announcements on the Forum, this instance of CDS will soon be decommissioned.
#  Please update your cdsapi package to a version >=0.7.0, create an account on CDS-Beta and update your .cdsapirc file. We strongly recommend users to check our Guidelines at https://confluence.ecmwf.int/x/uINmFw
#  The current legacy system will be kept for a while, but we will reduce resources gradually until full decommissioning in September 2024.
# 2024-08-12 14:40:58,480 WARNING MOVE TO CDS-Beta
# 2024-08-12 14:40:58,481 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-complete
# 2024-08-12 14:40:58,751 INFO Request is queued
# 2024-08-12 14:41:31,919 INFO Request is running
# 2024-08-12 15:57:41,471 INFO Request is completed
# 2024-08-12 15:57:41,473 INFO Downloading https://download-0017.copernicus-climate.eu/cache-compute-0017/cache/data4/adaptor.mars.external-1723495285.7766716-12233-11-dc4d1f7f-a3c3-412f-b8c7-402d0dd5353f.grib to /glade/derecho/scratch/rneale/ERA5/download/dtdt_param_1991_01_ytest_era5_modelevs.grib (5.5G)
# 2024-08-12 16:03:49,080 INFO Download rate 15.4M/s
# 2024-08-12 16:03:49,865 INFO Welcome to the CDS.
#  As per our announcements on the Forum, this instance of CDS will soon be decommissioned.
#  Please update your cdsapi package to a version >=0.7.0, create an account on CDS-Beta and update your .cdsapirc file. We strongly recommend users to check our Guidelines at https://confluence.ecmwf.int/x/uINmFw
#  The current legacy system will be kept for a while, but we will reduce resources gradually until full decommissioning in September 2024.
# 2024-08-12 16:03:49,866 WARNING MOVE TO CDS-Beta
# 2024-08-12 16:03:49,867 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-complete
# -For year = 1991 and month = 2
# 1991-02-01/1991-02-02/1991-02-03/1991-02-04/1991-02-05/1991-02-06/1991-02-07/1991-02-08/1991-02-09/1991-02-10/1991-02-11/1991-02-12/1991-02-13/1991-02-14/1991-02-15/1991-02-16/1991-02-17/1991-02-18/1991-02-19/1991-02-20/1991-02-21/1991-02-22/1991-02-23/1991-02-24/1991-02-25/1991-02-26/1991-02-27/1991-02-28
# -Ouput file /glade/derecho/scratch/rneale/ERA5/download/dtdt_param_1991_02_ytest_era5_modelevs.grib
# 2024-08-12 16:03:50,104 INFO Request is queued
# 2024-08-12 16:03:58,806 INFO Request is running
# 2024-08-12 17:20:32,061 INFO Request is completed
# 2024-08-12 17:20:32,062 INFO Downloading https://download-0013-clone.copernicus-climate.eu/cache-compute-0013/cache/data0/adaptor.mars.external-1723500238.3019755-27380-8-554552b8-4b42-47f9-9abc-65757585ddb5.grib to /glade/derecho/scratch/rneale/ERA5/download/dtdt_param_1991_02_ytest_era5_modelevs.grib (5G)
#  74%|███████▍  | 3.68G/4.99G [05:55<01:26, 16.3MB/s]    2024-08-12 18:33:26,550 INFO Request is completed
# 2024-08-12 18:33:26,551 INFO Downloading https://download-0000-clone.copernicus-climate.eu/cache-compute-0000/cache/data4/adaptor.mars.external-1723505360.2807357-31202-13-42d017fc-2fac-440e-86ea-8a4f2ed8be35.grib to /glade/derecho/scratch/rneale/ERA5/download/dtdt_param_1991_03_ytest_era5_modelevs.grib (5.5G)
# 2024-08-12 18:42:30,381 INFO Download rate 10.4M/s
# 2024-08-12 18:42:31,213 INFO Welcome to the CDS.
#  As per our announcements on the Forum, this instance of CDS will soon be decommissioned.
#  Please update your cdsapi package to a version >=0.7.0, create an account on CDS-Beta and update your .cdsapirc file. We strongly recommend users to check our Guidelines at https://confluence.ecmwf.int/x/uINmFw
#  The current legacy system will be kept for a while, but we will reduce resources gradually until full decommissioning in September 2024.
# 2024-08-12 18:42:31,214 WARNING MOVE TO CDS-Beta
# 2024-08-12 18:42:31,215 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-complete
# -For year = 1991 and month = 4
# 1991-04-01/1991-04-02/1991-04-03/1991-04-04/1991-04-05/1991-04-06/1991-04-07/1991-04-08/1991-04-09/1991-04-10/1991-04-11/1991-04-12/1991-04-13/1991-04-14/1991-04-15/1991-04-16/1991-04-17/1991-04-18/1991-04-19/1991-04-20/1991-04-21/1991-04-22/1991-04-23/1991-04-24/1991-04-25/1991-04-26/1991-04-27/1991-04-28/1991-04-29/1991-04-30
# -Ouput file /glade/derecho/scratch/rneale/ERA5/download/dtdt_param_1991_04_ytest_era5_modelevs.grib
# 2024-08-12 18:42:31,400 INFO Request is queued
# 2024-08-12 18:43:47,613 INFO Request is running
# 2024-08-12 20:13:17,540 INFO Request is completed
# 2024-08-12 20:13:17,541 INFO Downloading https://download-0005-clone.copernicus-climate.eu/cache-compute-0005/cache/data3/adaptor.mars.external-1723509804.733805-5433-10-d4910c36-fbd4-4866-aa8e-7035e5346c91.grib to /glade/derecho/scratch/rneale/ERA5/download/dtdt_param_1991_04_ytest_era5_modelevs.grib (5.3G)
#  26%|██▌       | 1.39G/5.34G [04:27<11:14, 6.29MB/s]

# %%
from datetime import datetime, timedelta

def generate_dates(year, month):
    # Create a datetime object for the first day of the given month
    start_date = datetime(year, month, 1)
    
    # Find the next month to determine the end date
    if month == 12:
        end_date = datetime(year + 1, 1, 1)
    else:
        end_date = datetime(year, month + 1, 1)
    
    # Calculate the number of days in the month
    delta = end_date - start_date
    
    # Generate a list of dates in the format yyyy-mm-dd
    dates = [(start_date + timedelta(days=i)).strftime("%Y-%m-%d") for i in range(delta.days)]

    # Concatenate the dates into a single string separated by '/'
    concatenated_dates = '/'.join(dates)

    # Info.
    print('-For year = '+str(year)+' and month = '+str(month))
    print(concatenated_dates)
    
    return concatenated_dates
