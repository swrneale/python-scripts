# %%
import matplotlib as mp
import xarray as xr

# %%
run_t = 'f.e21.F2000climo.f19_f19.cesm2_1.zmke.004'
run_c = 'f.e21.F2000climo.f19_f19.cesm2_1.zmke.003'
season = 'DJF'



dir_in = '/glade/work/rneale/amwg_diag/'


df_c = xr.open_dataset(dir_in+run_c+'/'+run_c+'_'+season+'_plotvars.nc')
df_t = xr.open_dataset(dir_in+run_t+'/'+run_t+'_'+season+'_plotvars.nc')

# %%
df_c
#df_c['PRECT'].plot()

da_diff = df_t['Q']-df_c['Q']
da_diff[10,:,:].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /glade/work/rneale/python/miniconda3/envs/neale_myenv/lib/python3.8/site-packages/xarray/core/dataset.py:1336, in Dataset._construct_dataarray(self, name)
#    1335 try:
# -> 1336     variable = self._variables[name]
#    1337 except KeyError:
#
# KeyError: 'Q'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [3], line 4
#       1 df_c
#       2 #df_c['PRECT'].plot()
# ----> 4 da_diff = df_t['Q']-df_c['Q']
#       5 da_diff[10,:,:].plot()
#
# File /glade/work/rneale/python/miniconda3/envs/neale_myenv/lib/python3.8/site-packages/xarray/core/dataset.py:1427, in Dataset.__getitem__(self, key)
#    1425     return self.isel(**key)
#    1426 if utils.hashable(key):
# -> 1427     return self._construct_dataarray(key)
# ...

# %%
df_c
# Out:
# <xarray.Dataset>
# Dimensions:           (lat: 96, lon: 144, ncl2: 1, ncl3: 1, lev_p: 25,
#                        ncl5: 25, ncl6: 96, ncl7: 25, ncl8: 96, ncl9: 25,
#                        ncl10: 96, lev: 25, ncl12: 25, ncl13: 96, ncl14: 25,
#                        ncl15: 96, ncl16: 96, ncl17: 144)
# Coordinates:
#   * lat               (lat) float64 -90.0 -88.11 -86.21 ... 86.21 88.11 90.0
#   * lon               (lon) float64 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
#   * lev_p             (lev_p) float32 30.0 50.0 70.0 100.0 ... 950.0 975.0 1e+03
#   * lev               (lev) float32 30.0 50.0 70.0 100.0 ... 950.0 975.0 1e+03
# Dimensions without coordinates: ncl2, ncl3, ncl5, ncl6, ncl7, ncl8, ncl9,
#                                 ncl10, ncl12, ncl13, ncl14, ncl15, ncl16, ncl17
# Data variables: (12/123)
#     RESTOM            (lat, lon) float32 ...
#     RESSURF           (lat, lon) float32 ...
#     SOLIN             (lat, lon) float32 ...
# ...
